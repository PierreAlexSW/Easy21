# %%
import numpy as np 
from Environment import Easy21
import matplotlib.pyplot as plt
from utils import *

# %%
N0 = 100
iterations = int(1e6)
discount_factor = 1
lambdas = [i/10 for i in range(11)]

A_V = td_montecarlo(iterations, N0, discount_factor)
plot_value_function(A_V, degree = 120,cm = plt.cm.plasma)
